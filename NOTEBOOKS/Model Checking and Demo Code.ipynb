# %% [markdown]
# Loading Dataframes

# %%
#note that hi1 and lo1 will denote models for DecisionTreeClassifier
#note that hi2 and lo2 will denote models for MLPClassifier
#note that hi3 and lo3 will denote models for HistGradientBoostingClassifier

import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, clear_output
from joblib import Parallel, delayed
import joblib

from sklearn import metrics
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Loading Training and Testing Set

# %%
from google.colab import drive
drive.mount('/content/drive')

data_dir = '/content/drive/MyDrive/CS180/Project/CS180_Project_cbragunton_jtderez/DATASETS/'
X1_train = pd.read_csv(data_dir + 'X1_train.csv')
X2_train = pd.read_csv(data_dir + 'X2_train.csv')
X1_test = pd.read_csv(data_dir + 'X1_test.csv')
X2_test = pd.read_csv(data_dir + 'X2_test.csv')
lo1_train = pd.read_csv(data_dir + 'lo1_train.csv')
lo2_train = pd.read_csv(data_dir + 'lo2_train.csv')
hi1_train = pd.read_csv(data_dir + 'hi1_train.csv')
hi2_train = pd.read_csv(data_dir + 'hi2_train.csv')
lo1_test = pd.read_csv(data_dir + 'lo1_test.csv')
lo2_test = pd.read_csv(data_dir + 'lo2_test.csv')
hi1_test = pd.read_csv(data_dir + 'hi1_test.csv')
hi2_test = pd.read_csv(data_dir + 'hi2_test.csv')

# %cd /content/drive/MyDrive/CS180/Project/CS180_Project_cbragunton_jtderez/MODELS

dir = '/content/drive/MyDrive/CS180/Project/CS180_Project_cbragunton_jtderez/MODELS'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/CS180/Project/CS180_Project_cbragunton_jtderez/IMPLEMENTATION

# %% [markdown]
# Decision Tree Classifier Models

# %% [markdown]
# Highest Region Game Sales

# %%
hi1_model = joblib.load('Highest_Region_DecisionTreeClassifier.pkl')

hi1_pred = pd.DataFrame(hi1_model.predict(X1_test))
print(hi1_pred.sample(15, random_state=427))
print(hi1_test.sample(15, random_state=427))
# Out:
#              0
# 466   NA_Sales
# 13    EU_Sales
# 754   NA_Sales
# 157   EU_Sales
# 1286  EU_Sales
# 453   EU_Sales
# 223   NA_Sales
# 683   NA_Sales
# 878   NA_Sales
# 454   NA_Sales
# 45    NA_Sales
# 364   EU_Sales
# 1247  NA_Sales
# 200   NA_Sales
# 777   EU_Sales
#        highest
# 466   NA_Sales
# 13    NA_Sales
# 754   NA_Sales
# 157   EU_Sales
# 1286  EU_Sales
# 453   EU_Sales
# 223   NA_Sales
# 683   NA_Sales
# 878   NA_Sales
# 454   NA_Sales
# 45    NA_Sales
# 364   EU_Sales
# 1247  NA_Sales
# 200   NA_Sales
# 777   NA_Sales

# %%
accuracy = accuracy_score(hi1_test, hi1_pred)
report = classification_report(hi1_test, hi1_pred)
print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:')
print(report)
# Out:
# Accuracy: 0.81
# Classification Report:
#               precision    recall  f1-score   support
#
#     EU_Sales       0.76      0.56      0.64       275
#     JP_Sales       0.61      0.31      0.41        91
#     NA_Sales       0.83      0.94      0.88       989
#  Other_Sales       0.00      0.00      0.00        10
#
#     accuracy                           0.81      1365
#    macro avg       0.55      0.45      0.48      1365
# weighted avg       0.80      0.81      0.80      1365
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# Lowest Region Game Sales

# %%
lo1_model = joblib.load('Lowest_Region_DecisionTreeClassifier.pkl')

lo1_pred = pd.DataFrame(lo1_model.predict(X1_test))
print(lo1_pred.sample(15, random_state=427))
print(lo1_test.sample(15, random_state=427))
# Out:
#                 0
# 466   Other_Sales
# 13       JP_Sales
# 754      EU_Sales
# 157      NA_Sales
# 1286     JP_Sales
# 453      JP_Sales
# 223      JP_Sales
# 683      JP_Sales
# 878      EU_Sales
# 454      JP_Sales
# 45       JP_Sales
# 364      JP_Sales
# 1247     JP_Sales
# 200      JP_Sales
# 777      JP_Sales
#            lowest
# 466   Other_Sales
# 13       JP_Sales
# 754      EU_Sales
# 157      NA_Sales
# 1286     JP_Sales
# 453      JP_Sales
# 223      JP_Sales
# 683      EU_Sales
# 878      EU_Sales
# 454      JP_Sales
# 45    Other_Sales
# 364      JP_Sales
# 1247     JP_Sales
# 200      JP_Sales
# 777      JP_Sales

# %%
accuracy = accuracy_score(lo1_test, lo1_pred)
report = classification_report(lo1_test, lo1_pred)
print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:')
print(report)
# Out:
# Accuracy: 0.76
# Classification Report:
#               precision    recall  f1-score   support
#
#     EU_Sales       0.58      0.44      0.50       207
#     JP_Sales       0.81      0.91      0.86       891
#     NA_Sales       0.68      0.55      0.61       132
#  Other_Sales       0.60      0.47      0.52       135
#
#     accuracy                           0.76      1365
#    macro avg       0.67      0.59      0.62      1365
# weighted avg       0.74      0.76      0.75      1365

# %% [markdown]
# MLP Classifier Models

# %% [markdown]
# Highest Region Game Sales

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPClassifier
scaler = MinMaxScaler(feature_range = (0,1))
X1_test = scaler.fit_transform(X1_test)
hi2_model = joblib.load('Highest_Region_MLPClassifier.pkl')

hi2_pred = pd.DataFrame(hi2_model.predict(X1_test))
print(hi2_pred.sample(15, random_state=427))
print(hi1_test.sample(15, random_state=427))
# Out:
#              0
# 466   JP_Sales
# 13    NA_Sales
# 754   NA_Sales
# 157   EU_Sales
# 1286  EU_Sales
# 453   EU_Sales
# 223   NA_Sales
# 683   NA_Sales
# 878   JP_Sales
# 454   NA_Sales
# 45    NA_Sales
# 364   EU_Sales
# 1247  NA_Sales
# 200   NA_Sales
# 777   NA_Sales
#        highest
# 466   NA_Sales
# 13    NA_Sales
# 754   NA_Sales
# 157   EU_Sales
# 1286  EU_Sales
# 453   EU_Sales
# 223   NA_Sales
# 683   NA_Sales
# 878   NA_Sales
# 454   NA_Sales
# 45    NA_Sales
# 364   EU_Sales
# 1247  NA_Sales
# 200   NA_Sales
# 777   NA_Sales

# %%
accuracy = accuracy_score(hi1_test, hi2_pred)
report = classification_report(hi1_test, hi2_pred)
print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:')
print(report)
# Out:
# Accuracy: 0.82
# Classification Report:
#               precision    recall  f1-score   support
#
#     EU_Sales       0.73      0.64      0.68       275
#     JP_Sales       0.53      0.51      0.52        91
#     NA_Sales       0.87      0.91      0.89       989
#  Other_Sales       0.25      0.10      0.14        10
#
#     accuracy                           0.82      1365
#    macro avg       0.60      0.54      0.56      1365
# weighted avg       0.81      0.82      0.81      1365

# %% [markdown]
# Lowest Region Game Sales

# %%
lo2_model = joblib.load('Lowest_Region_MLPClassifier.pkl')

lo2_pred = pd.DataFrame(lo2_model.predict(X1_test))
print(lo2_pred.sample(15, random_state=427))
print(lo1_test.sample(15, random_state=427))
# Out:
#              0
# 466   NA_Sales
# 13    JP_Sales
# 754   EU_Sales
# 157   NA_Sales
# 1286  JP_Sales
# 453   JP_Sales
# 223   JP_Sales
# 683   EU_Sales
# 878   EU_Sales
# 454   JP_Sales
# 45    JP_Sales
# 364   NA_Sales
# 1247  JP_Sales
# 200   JP_Sales
# 777   JP_Sales
#            lowest
# 466   Other_Sales
# 13       JP_Sales
# 754      EU_Sales
# 157      NA_Sales
# 1286     JP_Sales
# 453      JP_Sales
# 223      JP_Sales
# 683      EU_Sales
# 878      EU_Sales
# 454      JP_Sales
# 45    Other_Sales
# 364      JP_Sales
# 1247     JP_Sales
# 200      JP_Sales
# 777      JP_Sales

# %%
accuracy = accuracy_score(lo1_test, lo2_pred)
report = classification_report(lo1_test, lo2_pred)
print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:')
print(report)
# Out:
# Accuracy: 0.76
# Classification Report:
#               precision    recall  f1-score   support
#
#     EU_Sales       0.55      0.54      0.54       207
#     JP_Sales       0.86      0.84      0.85       891
#     NA_Sales       0.66      0.65      0.66       132
#  Other_Sales       0.56      0.66      0.60       135
#
#     accuracy                           0.76      1365
#    macro avg       0.66      0.67      0.66      1365
# weighted avg       0.76      0.76      0.76      1365

# %% [markdown]
# Hist Gradient Boosting Classifier

# %% [markdown]
# Highest Region Game Sales

# %%
hi3_model = joblib.load('Highest_Region_HistGradientBoostingClassifierClassifier.pkl')

hi3_pred = pd.DataFrame(hi3_model.predict(X2_test))
print(hi3_pred.sample(15, random_state=427))
print(hi2_test.sample(15, random_state=427))
# Out:
#              0
# 744   NA_Sales
# 1094  JP_Sales
# 224   NA_Sales
# 2530  NA_Sales
# 655   NA_Sales
# 2209  JP_Sales
# 3114  JP_Sales
# 908   NA_Sales
# 2334  NA_Sales
# 1184  NA_Sales
# 329   NA_Sales
# 2674  JP_Sales
# 1876  EU_Sales
# 607   JP_Sales
# 2418  NA_Sales
#        highest
# 744   NA_Sales
# 1094  JP_Sales
# 224   NA_Sales
# 2530  EU_Sales
# 655   NA_Sales
# 2209  JP_Sales
# 3114  JP_Sales
# 908   NA_Sales
# 2334  NA_Sales
# 1184  NA_Sales
# 329   EU_Sales
# 2674  JP_Sales
# 1876  NA_Sales
# 607   JP_Sales
# 2418  NA_Sales

# %%
accuracy = accuracy_score(hi2_test, hi3_pred)
report = classification_report(hi2_test, hi3_pred)
print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:')
print(report)
# Out:
# Accuracy: 0.86
# Classification Report:
#               precision    recall  f1-score   support
#
#     EU_Sales       0.80      0.62      0.70       497
#     JP_Sales       0.86      0.87      0.87       765
#     NA_Sales       0.88      0.92      0.90      2066
#  Other_Sales       0.25      0.06      0.10        16
#
#     accuracy                           0.86      3344
#    macro avg       0.70      0.62      0.64      3344
# weighted avg       0.86      0.86      0.86      3344

# %% [markdown]
# Lowest Region Game Sales

# %%
lo3_model = joblib.load('Lowest_Region_HistGradientBoostingClassifierClassifier.pkl')

lo3_pred = pd.DataFrame(lo3_model.predict(X2_test))
print(lo3_pred.sample(15, random_state=427))
print(lo2_test.sample(15, random_state=427))
# Out:
#                 0
# 744      JP_Sales
# 1094     NA_Sales
# 224      JP_Sales
# 2530     JP_Sales
# 655      JP_Sales
# 2209     NA_Sales
# 3114     NA_Sales
# 908      JP_Sales
# 2334     JP_Sales
# 1184     JP_Sales
# 329      EU_Sales
# 2674     NA_Sales
# 1876  Other_Sales
# 607      NA_Sales
# 2418     JP_Sales
#            lowest
# 744      JP_Sales
# 1094     NA_Sales
# 224      JP_Sales
# 2530     JP_Sales
# 655      JP_Sales
# 2209     NA_Sales
# 3114     NA_Sales
# 908      JP_Sales
# 2334     JP_Sales
# 1184     JP_Sales
# 329      NA_Sales
# 2674     NA_Sales
# 1876  Other_Sales
# 607      NA_Sales
# 2418     JP_Sales

# %%
accuracy = accuracy_score(lo2_test, lo3_pred)
report = classification_report(lo2_test, lo3_pred)
print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:')
print(report)
# Out:
# Accuracy: 0.83
# Classification Report:
#               precision    recall  f1-score   support
#
#     EU_Sales       0.73      0.67      0.70       543
#     JP_Sales       0.87      0.90      0.88      1698
#     NA_Sales       0.85      0.88      0.87       890
#  Other_Sales       0.70      0.57      0.63       213
#
#     accuracy                           0.83      3344
#    macro avg       0.79      0.76      0.77      3344
# weighted avg       0.83      0.83      0.83      3344
